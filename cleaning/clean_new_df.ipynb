# %%
import pandas as pd

# %%
df = pd.read_csv("new_data_set.csv")

# %%
pd.set_option("display.max_column",500)
pd.set_option("display.max_row",500)

# %%
df.head()
# Out:
#    Unnamed: 0  Year          Province  Table_1 | Number of Schools  \
# 0           0  2016  Banteay Meanchey                        774.0
# 1           1  2016        Battambang                       1044.0
# 2           2  2016      Kampong Cham                        757.0
# 3           3  2016   Kampong Chhnang                        447.0
# 4           4  2016      Kampong Speu                        562.0
#
#    Table_1 | Number of Classes  Table_1 | Classes in Pagoda  \
# 0                       4276.0                         21.0
# 1                       6995.0                         20.0
# 2                       5544.0                        108.0
# 3                       3093.0                         14.0
# 4                       4017.0                         33.0
#
#    Table_1 | Enrollment | Total  Table_1 | Enrollment | Girl  \
# 0                      139995.0                      69636.0
# 1                      233906.0                     115311.0
# ...

# %%
print ("hello'")

# %%
df[df['Year']==2026]
# Out:
#      Unnamed: 0  Year          Province  Table_1 | Number of Schools  \
# 250         250  2026  Banteay Meanchey                        515.0
# 251         251  2026        Battambang                        809.0
# 252         252  2026      Kampong Cham                        541.0
# 253         253  2026   Kampong Chhnang                        392.0
# 254         254  2026      Kampong Speu                        425.0
# 255         255  2026      Kampong Thom                        603.0
# 256         256  2026            Kampot                        420.0
# 257         257  2026            Kandal                        551.0
# 258         258  2026               Kep                         30.0
# 259         259  2026          Koh Kong                        139.0
# 260         260  2026            Kratie                        356.0
# 261         261  2026       Mondul Kiri                        110.0
# 262         262  2026    Otdar Meanchey                        273.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Columns: 263 entries, Unnamed: 0 to Table_21 | Grade 12 | Dropout
# dtypes: float64(240), int64(2), object(21)
# memory usage: 565.2+ KB

# %%
# Returns a DataFrame containing only 'object' columns
object_columns = df.select_dtypes(include=['object'])
print(object_columns)
# Out:
#              Province Table_19 | Grade 1 | Dropout  \
# 0    Banteay Meanchey                          5.4
# 1          Battambang                          6.9
# 2        Kampong Cham                          3.9
# 3     Kampong Chhnang                          2.5
# 4        Kampong Speu                          6.3
# 5        Kampong Thom                         19.1
# 6              Kampot                          4.0
# 7              Kandal                          1.2
# 8                 Kep                          1.9
# 9            Koh Kong                         17.2
# 10             Kratie                          5.9
# 11        Mondul Kiri                          4.7
# 12     Otdar Meanchey                          4.6
# 13             Pailin                          8.2
# 14         Phnom Penh                          5.4
# 15     Preah Sihanouk                          0.5
# 16       Preah Vihear                          9.9
# ...

# %%
# Create a list of all columns except 'Province'
cols_to_fix = df.columns.difference(['Province'])

# Convert those columns to float
df[cols_to_fix] = df[cols_to_fix].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275 entries, 0 to 274
# Columns: 263 entries, Unnamed: 0 to Table_21 | Grade 12 | Dropout
# dtypes: float64(260), int64(2), object(1)
# memory usage: 565.2+ KB

# %%
# Returns a DataFrame containing only columns with at least one NaN
df_filtered = df[df.columns[df.isnull().any()]]
df_filtered.isna().sum()
# Out:
# Table_19 | Grade 1 | Dropout       4
# Table_19 | Grade 2 | Promotion     1
# Table_19 | Grade 2 | Dropout       5
# Table_19 | Grade 3 | Promotion     1
# Table_19 | Grade 3 | Dropout       3
# Table_19 | Grade 4 | Promotion     1
# Table_19 | Grade 4 | Dropout       1
# Table_20 | Grade 5 | Promotion     2
# Table_20 | Grade 5 | Dropout       2
# Table_20 | Grade 6 | Dropout       2
# Table_20 | Grade 7 | Promotion     1
# Table_20 | Grade 7 | Dropout       1
# Table_20 | Grade 8 | Promotion     1
# Table_20 | Grade 8 | Dropout       1
# Table_21 | Grade 10 | Promotion    1
# Table_21 | Grade 10 | Dropout      2
# Table_21 | Grade 11 | Promotion    4
# Table_21 | Grade 11 | Dropout      5
# Table_21 | Grade 12 | Promotion    2
# Table_21 | Grade 12 | Dropout      2
# dtype: int64

# %%
# 1. Identify numeric columns (everything except 'Province')
numeric_cols = df.select_dtypes(include=['number']).columns

# 2. Fill NaNs in those columns with their own mean
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# 3. Verify there are no more missing values
print(df.isnull().sum().sum())
# Out:
# 0

# %%
cols = df.columns.tolist()
    
# Print 5 columns per line
for i in range(0, len(cols), 5):
    print(f"{i:3}: {', '.join(cols[i:i+5])}")
# Out:
#   0: Unnamed: 0, Year, Province, Table_1 | Number of Schools, Table_1 | Number of Classes
#   5: Table_1 | Classes in Pagoda, Table_1 | Enrollment | Total, Table_1 | Enrollment | Girl, Table_1 | Repeaters | Total, Table_1 | Repeaters | Girl
#  10: Table_1 | Teaching Staff | Total, Table_1 | Teaching Staff | Female, Table_1 | Non-Teaching Staff | Total, Table_1 | Non-Teaching Staff | Female, Table_1 | Total Staff | Total
#  15: Table_1 | Total Staff | Female, Table_2 | Number of Schools | Pre-Sch., Table_2 | Number of Schools | Primary, Table_2 | Number of Schools | College, Table_2 | Number of Schools | Lycee
#  20: Table_2 | 2 - Shift Schools | Lycee, Table_2 | Floating Schools | Lycee, Table_2 | Schools in Pagoda | Lycee, Table_2 | Attached Pre-Sch. | Lycee, Table_2 | Schools Without | Water Sup.
# ...

# %%
rename_map = {
    "Unnamed: 0": "row_id",
    "Year": "Year",
    "Province": "Province",

    # --- General school info ---
    "Table_1 | Number of Schools": "num_schools",
    "Table_1 | Disadv. Schools": "num_disadvantaged_schools",
    "Table_1 | Number of Classes": "num_classes",
    "Table_1 | Classes in Pagoda": "classes_in_pagoda",
    "Table_1 | Enrollment | Total": "enrollment_total",
    "Table_1 | Enrollment | Girl": "enrollment_girl",
    "Table_1 | Repeaters | Total": "repeaters_total",
    "Table_1 | Repeaters | Girl": "repeaters_girl",
    "Table_1 | Teaching Staff | Total": "teaching_staff_total",
    "Table_1 | Teaching Staff | Female": "teaching_staff_female",
    "Table_1 | Non-Teaching Staff | Total": "non_teaching_staff_total",
    "Table_1 | Non-Teaching Staff | Female": "non_teaching_staff_female",
    "Table_1 | Total Staff | Total": "total_staff_total",
    "Table_1 | Total Staff | Female": "total_staff_female",

    # --- Schools by level ---
    "Table_2 | Number of Schools | Pre-Sch.": "num_schools_preschool",
    "Table_2 | Number of Schools | Primary": "num_schools_primary",
    "Table_2 | Number of Schools | College": "num_schools_college",
    "Table_2 | Number of Schools | Lycee": "num_schools_lycee",
    "Table_2 | 2 - Shift Schools | Lycee": "two_shift_schools_lycee",
    "Table_2 | Floating Schools | Lycee": "floating_schools_lycee",
    "Table_2 | Schools in Pagoda | Lycee": "schools_in_pagoda_lycee",
    "Table_2 | Attached Pre-Sch. | Lycee": "attached_preschool_lycee",
    "Table_2 | Schools Without | Water Sup.": "schools_without_water",
    "Table_2 | Schools Without | Latrine": "schools_without_latrine",
    "Table_2 | Characteristics of School Principals (Incharge) | Avg. Age": "principal_avg_age",
    "Table_2 | Characteristics of School Principals (Incharge) | Avg.Service": "principal_avg_service_years",
    "Table_2 | Characteristics of School Principals (Incharge) | U.Sec+ Ed.": "principal_upper_sec_plus_edu",
    "Table_2 | Characteristics of School Principals (Incharge) | Female": "principal_female",

    # --- Cluster & satellite schools ---
    "Table_3 | Number of Primary Schools": "num_primary_schools",
    "Table_3 | Number of Cluster Schools": "num_cluster_schools",
    "Table_3 | Satelite School | school": "satellite_schools",
    "Table_3 | Satelite School | class": "satellite_classes",
    "Table_3 | Number of schools in Pagoda | Pre school Schools": "pagoda_preschool_schools",
    "Table_3 | Number of schools in Pagoda | Pre school Classes": "pagoda_preschool_classes",
    "Table_3 | Number of schools in Pagoda | Primary School Schools": "pagoda_primary_schools",
    "Table_3 | Number of schools in Pagoda | Primary School Classes": "pagoda_primary_classes",
    "Table_3 | Number of schools in Pagoda | Junior high school Schools": "pagoda_junior_high_schools",
    "Table_3 | Number of schools in Pagoda | Junior high school Classes": "pagoda_junior_high_classes",
    "Table_3 | Number of schools in Pagoda | Senior high school Schools": "pagoda_senior_high_schools",
    "Table_3 | Number of schools in Pagoda | Senior high school Classes": "pagoda_senior_high_classes",

    # --- Grade 1-3 enrollment & repeaters ---
    "Table_4 | Enrollment in Grade 1 | Total": "g1_enrollment_total",
    "Table_4 | Enrollment in Grade 1 | Girl": "g1_enrollment_girl",
    "Table_4 | Repeaters in Grade 1 | Total": "g1_repeaters_total",
    "Table_4 | Repeaters in Grade 1 | Girl": "g1_repeaters_girl",
    "Table_4 | Enrollment in Grade 2 | Total": "g2_enrollment_total",
    "Table_4 | Enrollment in Grade 2 | Girl": "g2_enrollment_girl",
    "Table_4 | Repeaters in Grade 2 | Total": "g2_repeaters_total",
    "Table_4 | Repeaters in Grade 2 | Girl": "g2_repeaters_girl",
    "Table_4 | Enrollment in Grade 3 | Total": "g3_enrollment_total",
    "Table_4 | Enrollment in Grade 3 | Girl": "g3_enrollment_girl",
    "Table_4 | Repeaters in Grade 3 | Total": "g3_repeaters_total",
    "Table_4 | Repeaters in Grade 3 | Girl": "g3_repeaters_girl",

    # --- Grade 4-6 enrollment & repeaters ---
    "Table_5 | Enrollment in Grade 4 | Total": "g4_enrollment_total",
    "Table_5 | Enrollment in Grade 4 | Girl": "g4_enrollment_girl",
    "Table_5 | Repeaters in Grade 4 | Total": "g4_repeaters_total",
    "Table_5 | Repeaters in Grade 4 | Girl": "g4_repeaters_girl",
    "Table_5 | Enrollment in Grade 5 | Total": "g5_enrollment_total",
    "Table_5 | Enrollment in Grade 5 | Girl": "g5_enrollment_girl",
    "Table_5 | Repeaters in Grade 5 | Total": "g5_repeaters_total",
    "Table_5 | Repeaters in Grade 5 | Girl": "g5_repeaters_girl",
    "Table_5 | Enrollment in Grade 6 | Total": "g6_enrollment_total",
    "Table_5 | Enrollment in Grade 6 | Girl": "g6_enrollment_girl",
    "Table_5 | Repeaters in Grade 6 | Total": "g6_repeaters_total",
    "Table_5 | Repeaters in Grade 6 | Girl": "g6_repeaters_girl",

    # --- Grade 7-9 enrollment & repeaters ---
    "Table_6 | Enrollment in Grade 7 | Total": "g7_enrollment_total",
    "Table_6 | Enrollment in Grade 7 | Girl": "g7_enrollment_girl",
    "Table_6 | Repeaters in Grade 7 | Total": "g7_repeaters_total",
    "Table_6 | Repeaters in Grade 7 | Girl": "g7_repeaters_girl",
    "Table_6 | Enrollment in Grade 8 | Total": "g8_enrollment_total",
    "Table_6 | Enrollment in Grade 8 | Girl": "g8_enrollment_girl",
    "Table_6 | Repeaters in Grade 8 | Total": "g8_repeaters_total",
    "Table_6 | Repeaters in Grade 8 | Girl": "g8_repeaters_girl",
    "Table_6 | Enrollment in Grade 9 | Total": "g9_enrollment_total",
    "Table_6 | Enrollment in Grade 9 | Girl": "g9_enrollment_girl",
    "Table_6 | Repeaters in Grade 9 | Total": "g9_repeaters_total",
    "Table_6 | Repeaters in Grade 9 | Girl": "g9_repeaters_girl",

    # --- Grade 10-12 enrollment & repeaters ---
    "Table_7 | Enrollment in Grade 10 | Total": "g10_enrollment_total",
    "Table_7 | Enrollment in Grade 10 | Girl": "g10_enrollment_girl",
    "Table_7 | Repeaters in Grade 10 | Total": "g10_repeaters_total",
    "Table_7 | Repeaters in Grade 10 | Girl": "g10_repeaters_girl",
    "Table_7 | Enrollment in Grade 11 | Total": "g11_enrollment_total",
    "Table_7 | Enrollment in Grade 11 | Girl": "g11_enrollment_girl",
    "Table_7 | Repeaters in Grade 11 | Total": "g11_repeaters_total",
    "Table_7 | Repeaters in Grade 11 | Girl": "g11_repeaters_girl",
    "Table_7 | Enrollment in Grade 12 | Total": "g12_enrollment_total",
    "Table_7 | Enrollment in Grade 12 | Girl": "g12_enrollment_girl",
    "Table_7 | Repeaters in Grade 12 | Total": "g12_repeaters_total",
    "Table_7 | Repeaters in Grade 12 | Girl": "g12_repeaters_girl",

    # --- Intake & over-age enrollment ---
    "Table_8 | Grade 1 Intake | Total": "g1_intake_total",
    "Table_8 | Grade 1 Intake | Aged 6": "g1_intake_aged6",
    "Table_8 | Primary Enrollment | Total": "primary_enrollment_total",
    "Table_8 | Primary Enrollment | Aged 11+": "primary_enrollment_aged11plus",
    "Table_8 | Grade 7 Intake | Total": "g7_intake_total",
    "Table_8 | Grade 7 Intake | Aged 12": "g7_intake_aged12",
    "Table_8 | L. Sec. Enrollment | Total": "lower_sec_enrollment_total",
    "Table_8 | L. Sec. Enrollment | Aged 14+": "lower_sec_enrollment_aged14plus",
    "Table_8 | Grade 10 Intake | Total": "g10_intake_total",
    "Table_8 | Grade 10 Intake | Aged 15": "g10_intake_aged15",
    "Table_8 | U. Sec. Enrollment | Total": "upper_sec_enrollment_total",
    "Table_8 | U. Sec. Enrollment | Aged 17+": "upper_sec_enrollment_aged17plus",
    "Table_8 | % Over-age Enrollment in | Primary": "pct_overage_enrollment_primary",
    "Table_8 | % Over-age Enrollment in | L. Sec.": "pct_overage_enrollment_lower_sec",
    "Table_8 | % Over-age Enrollment in | U. Sec.": "pct_overage_enrollment_upper_sec",

    # --- Staff education level ---
    "Table_9 | Education Level of Teaching Staff | Primary": "teaching_staff_edu_primary",
    "Table_9 | Education Level of Teaching Staff | L.Sec.": "teaching_staff_edu_lower_sec",
    "Table_9 | Education Level of Teaching Staff | U.Sec.": "teaching_staff_edu_upper_sec",
    "Table_9 | Education Level of Teaching Staff | Graduate": "teaching_staff_edu_graduate",
    "Table_9 | Education Level of Teaching Staff | Post Gaduate": "teaching_staff_edu_postgrad",
    "Table_9 | Education Level of Teaching Staff | PhD": "teaching_staff_edu_phd",
    "Table_9 | Education Level of Non-Teaching Staff | Primary": "non_teaching_staff_edu_primary",
    "Table_9 | Education Level of Non-Teaching Staff | L.Sec.": "non_teaching_staff_edu_lower_sec",
    "Table_9 | Education Level of Non-Teaching Staff | U.Sec.": "non_teaching_staff_edu_upper_sec",
    "Table_9 | Education Level of Non-Teaching Staff | Graduate": "non_teaching_staff_edu_graduate",
    "Table_9 | Education Level of Non-Teaching Staff | Post Graduate": "non_teaching_staff_edu_postgrad",
    "Table_9 | Education Level of Non-Teaching Staff | PhD": "non_teaching_staff_edu_phd",
    "Table_9 | Teaching Staff without Pedagogy Training | Primary": "teaching_staff_no_pedagogy_primary",
    "Table_9 | Teaching Staff without Pedagogy Training | L.Sec.": "teaching_staff_no_pedagogy_lower_sec",
    "Table_9 | Teaching Staff without Pedagogy Training | U.Sec.": "teaching_staff_no_pedagogy_upper_sec",
    "Table_9 | Teaching Staff without Pedagogy Training | Graduate": "teaching_staff_no_pedagogy_graduate",
    "Table_9 | Teaching Staff without Pedagogy Training | Post Graduate": "teaching_staff_no_pedagogy_postgrad",
    "Table_9 | Teaching Staff without Pedagogy Training | PhD": "teaching_staff_no_pedagogy_phd",

    # --- Buildings & infrastructure ---
    "Table_10 | Total Number of | Buildings": "num_buildings_total",
    "Table_10 | Total Number of | Rooms": "num_rooms_total",
    "Table_10 | Concrete/Brick Structure | Buildings": "concrete_brick_buildings",
    "Table_10 | Concrete/Brick Structure | Rooms": "concrete_brick_rooms",
    "Table_10 | Wooden Structure | Buildings": "wooden_buildings",
    "Table_10 | Wooden Structure | Rooms": "wooden_rooms",
    "Table_10 | Bamboo Structure | Buildings": "bamboo_buildings",
    "Table_10 | Bamboo Structure | Rooms": "bamboo_rooms",
    "Table_10 | New Buildings | Repaired": "buildings_repaired",
    "Table_10 | New Buildings | Constructed": "buildings_constructed",
    "Table_10 | Buildings Without Good | Floor": "buildings_poor_floor",
    "Table_10 | Buildings Without Good | Roof": "buildings_poor_roof",
    "Table_10 | Buildings Without Good | Wall": "buildings_poor_wall",

    # --- Classrooms ---
    "Table_11 | Number of Classrooms": "num_classrooms",
    "Table_11 | Number of Classrooms | in Pagoda": "classrooms_in_pagoda",
    "Table_11 | Number of Classrooms | New Repaired": "classrooms_repaired",
    "Table_11 | Number of Classrooms | New Constr.": "classrooms_constructed",
    "Table_11 | Classrooms Without Good | Floor": "classrooms_poor_floor",
    "Table_11 | Classrooms Without Good | Roof": "classrooms_poor_roof",
    "Table_11 | Classrooms Without Good | Wall": "classrooms_poor_wall",
    "Table_11 | Schools with Separate | Office": "schools_with_office",
    "Table_11 | Schools with Separate | Library": "schools_with_library",

    # --- School area & sports ---
    "Table_12 | School Area (m2) | Land": "school_area_land_m2",
    "Table_12 | School Area (m2) | Playground": "school_area_playground_m2",
    "Table_12 | Cl.room Area per Student | Playground": "classroom_area_per_student",
    "Table_12 | Pre-School with Sport Facility | Playground": "preschool_with_sport_facility",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | Volleyball": "sport_volleyball",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | Football": "sport_football",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | Basketball": "sport_basketball",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | Climb.Ropes": "sport_climbing_ropes",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | Shotput": "sport_shotput",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | High Jump": "sport_high_jump",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | Long Jump": "sport_long_jump",
    "Table_12 | Schools with Sport Ground, Equipment and Teams / Player for | Running": "sport_running",

    # --- Community & funding ---
    "Table_13 | Parent Association | Exists": "parent_assoc_exists",
    "Table_13 | Parent Association | Held Meet.": "parent_assoc_held_meeting",
    "Table_13 | Parent Association | Total": "parent_assoc_members_total",
    "Table_13 | Parent Association | Female": "parent_assoc_members_female",
    "Table_13 | Commu. | Teachers": "community_teachers",
    "Table_13 | Teaching | Monks": "teaching_monks",
    "Table_13 | PB Fund (Riel) | per Student": "pb_fund_per_student_riel",
    "Table_13 | PB Fund (Riel) | per School": "pb_fund_per_school_riel",
    "Table_13 | Number of Schools Obtaining Funds from | Sch. Income": "funding_school_income",
    "Table_13 | Number of Schools Obtaining Funds from | Community": "funding_community",
    "Table_13 | Number of Schools Obtaining Funds from | Gvt. For building": "funding_govt_building",
    "Table_13 | Number of Schools Obtaining Funds from | Abroad": "funding_abroad",
    "Table_13 | Number of Schools Obtaining Funds from | IOs/NGOs": "funding_ios_ngos",

    # --- Population by age group ---
    "Table_14 | Aged 6 | Total": "pop_aged6_total",
    "Table_14 | Aged 6 | Girl": "pop_aged6_girl",
    "Table_14 | Aged 6-11 | Total": "pop_aged6_11_total",
    "Table_14 | Aged 6-11 | Girl": "pop_aged6_11_girl",
    "Table_14 | Aged 12-14 | Total": "pop_aged12_14_total",
    "Table_14 | Aged 12-14 | Girl": "pop_aged12_14_girl",
    "Table_14 | Aged 15-17 | Total": "pop_aged15_17_total",
    "Table_14 | Aged 15-17 | Girl": "pop_aged15_17_girl",
    "Table_14 | Sex-Ratio of Population | Aged 6": "sex_ratio_aged6",
    "Table_14 | Sex-Ratio of Population | 6-11": "sex_ratio_aged6_11",
    "Table_14 | Sex-Ratio of Population | 12-14": "sex_ratio_aged12_14",
    "Table_14 | Sex-Ratio of Population | 15-17": "sex_ratio_aged15_17",

    # --- School efficiency ratios ---
    "Table_15 | Pupils per School": "pupils_per_school",
    "Table_15 | Teachers per School": "teachers_per_school",
    "Table_15 | Staff per School": "staff_per_school",
    "Table_15 | Buildings per School": "buildings_per_school",
    "Table_15 | Rooms per School": "rooms_per_school",
    "Table_15 | Classrooms per School": "classrooms_per_school",
    "Table_15 | Classes per School": "classes_per_school",
    "Table_15 | Percentage of Schools | 2 - shift": "pct_schools_two_shift",
    "Table_15 | Percentage of Schools | in Pagoda": "pct_schools_in_pagoda",
    "Table_15 | Percentage of Schools | w/o Water": "pct_schools_without_water",
    "Table_15 | Percentage of Schools | w/o Toilet": "pct_schools_without_toilet",

    # --- Pupil ratios ---
    "Table_16 | Pupil Teacher Ratio": "pupil_teacher_ratio",
    "Table_16 | Pupil Staff Ratio": "pupil_staff_ratio",
    "Table_16 | Pupil Class Ratio": "pupil_class_ratio",
    "Table_16 | Pupil Classroom Ratio": "pupil_classroom_ratio",
    "Table_16 | Classes per Classroom": "classes_per_classroom",
    "Table_16 | Classroom Area (m2) per Pupil": "classroom_area_per_pupil_m2",
    "Table_16 | Percentage of Total Students in | Pre-school": "pct_students_preschool",
    "Table_16 | Percentage of Total Students in | Primary": "pct_students_primary",
    "Table_16 | Percentage of Total Students in | Lower Secondary": "pct_students_lower_sec",
    "Table_16 | Percentage of Total Students in | Upper Secondary": "pct_students_upper_sec",
    "Table_16 | Percentage of | Non-tching Staff": "pct_non_teaching_staff",
    "Table_16 | Percentage of | Female Staff": "pct_female_staff",

    # --- Repeater & over-age rates ---
    "Table_17 | % Repeaters (Total) | Primary": "pct_repeaters_total_primary",
    "Table_17 | % Repeaters (Total) | L.Sec.": "pct_repeaters_total_lower_sec",
    "Table_17 | % Repeaters (Total) | U.Sec.": "pct_repeaters_total_upper_sec",
    "Table_17 | % Over-age Enrollment (Total) | Primary": "pct_overage_total_primary",
    "Table_17 | % Over-age Enrollment (Total) | L.Sec.": "pct_overage_total_lower_sec",
    "Table_17 | % Over-age Enrollment (Total) | U.Sec.": "pct_overage_total_upper_sec",
    "Table_17 | % Repeaters (Girl) | Primary": "pct_repeaters_girl_primary",
    "Table_17 | % Repeaters (Girl) | L.Sec.": "pct_repeaters_girl_lower_sec",
    "Table_17 | % Repeaters (Girl) | U.Sec.": "pct_repeaters_girl_upper_sec",
    "Table_17 | % Over-age Enrollment  (Girl) | Primary": "pct_overage_girl_primary",
    "Table_17 | % Over-age Enrollment  (Girl) | L.Sec.": "pct_overage_girl_lower_sec",
    "Table_17 | % Over-age Enrollment  (Girl) | U.Sec.": "pct_overage_girl_upper_sec",

    # --- Admission & transition rates ---
    "Table_18 | Gross Admission Rate | Total": "gross_admission_rate_total",
    "Table_18 | Gross Admission Rate | Girl": "gross_admission_rate_girl",
    "Table_18 | Net Admission Rate | Total": "net_admission_rate_total",
    "Table_18 | Net Admission Rate | Girl": "net_admission_rate_girl",
    "Table_18 | % Over-age (6+) Admission | Total": "pct_overage_admission_total",
    "Table_18 | % Over-age (6+) Admission | Girl": "pct_overage_admission_girl",
    "Table_18 | Transition Rate to Lower Sec. 2014/2015 | Total": "transition_rate_lower_sec_total",
    "Table_18 | Transition Rate to Lower Sec. 2014/2015 | Girl": "transition_rate_lower_sec_girl",
    "Table_18 | Transition Rate to Upper Sec. 2014/2015 | Total": "transition_rate_upper_sec_total",
    "Table_18 | Transition Rate to Upper Sec. 2014/2015 | Girl": "transition_rate_upper_sec_girl",

    # --- Grade promotion / repetition / dropout (G1-G4) ---
    "Table_19 | Grade 1 | Promotion": "g1_promotion",
    "Table_19 | Grade 1 | Repetition": "g1_repetition",
    "Table_19 | Grade 1 | Dropout": "g1_dropout",
    "Table_19 | Grade 2 | Promotion": "g2_promotion",
    "Table_19 | Grade 2 | Repetition": "g2_repetition",
    "Table_19 | Grade 2 | Dropout": "g2_dropout",
    "Table_19 | Grade 3 | Promotion": "g3_promotion",
    "Table_19 | Grade 3 | Repetition": "g3_repetition",
    "Table_19 | Grade 3 | Dropout": "g3_dropout",
    "Table_19 | Grade 4 | Promotion": "g4_promotion",
    "Table_19 | Grade 4 | Repetition": "g4_repetition",
    "Table_19 | Grade 4 | Dropout": "g4_dropout",

    # --- Grade promotion / repetition / dropout (G5-G8) ---
    "Table_20 | Grade 5 | Promotion": "g5_promotion",
    "Table_20 | Grade 5 | Repetition": "g5_repetition",
    "Table_20 | Grade 5 | Dropout": "g5_dropout",
    "Table_20 | Grade 6 | Promotion": "g6_promotion",
    "Table_20 | Grade 6 | Repetition": "g6_repetition",
    "Table_20 | Grade 6 | Dropout": "g6_dropout",
    "Table_20 | Grade 7 | Promotion": "g7_promotion",
    "Table_20 | Grade 7 | Repetition": "g7_repetition",
    "Table_20 | Grade 7 | Dropout": "g7_dropout",
    "Table_20 | Grade 8 | Promotion": "g8_promotion",
    "Table_20 | Grade 8 | Repetition": "g8_repetition",
    "Table_20 | Grade 8 | Dropout": "g8_dropout",

    # --- Grade promotion / repetition / dropout (G9-G12) ---
    "Table_21 | Grade 9 | Promotion": "g9_promotion",
    "Table_21 | Grade 9 | Repetition": "g9_repetition",
    "Table_21 | Grade 9 | Dropout": "g9_dropout",
    "Table_21 | Grade 10 | Promotion": "g10_promotion",
    "Table_21 | Grade 10 | Repetition": "g10_repetition",
    "Table_21 | Grade 10 | Dropout": "g10_dropout",
    "Table_21 | Grade 11 | Promotion": "g11_promotion",
    "Table_21 | Grade 11 | Repetition": "g11_repetition",
    "Table_21 | Grade 11 | Dropout": "g11_dropout",
    "Table_21 | Grade 12 | Promotion": "g12_promotion",
    "Table_21 | Grade 12 | Repetition": "g12_repetition",
    "Table_21 | Grade 12 | Dropout": "g12_dropout",
}

df = df.rename(columns=rename_map)

# %%
cols = df.columns.tolist()

# Print 5 columns per line
for i in range(0, len(cols), 5):
    print(f"{i:3}: {', '.join(cols[i:i+5])}")
# Out:
#   0: row_id, Year, Province, num_schools, num_classes
#   5: classes_in_pagoda, enrollment_total, enrollment_girl, repeaters_total, repeaters_girl
#  10: teaching_staff_total, teaching_staff_female, non_teaching_staff_total, non_teaching_staff_female, total_staff_total
#  15: total_staff_female, num_schools_preschool, num_schools_primary, num_schools_college, num_schools_lycee
#  20: two_shift_schools_lycee, floating_schools_lycee, schools_in_pagoda_lycee, attached_preschool_lycee, schools_without_water
#  25: schools_without_latrine, principal_avg_age, principal_avg_service_years, principal_upper_sec_plus_edu, principal_female
#  30: num_primary_schools, num_cluster_schools, satellite_schools, satellite_classes, pagoda_preschool_schools
#  35: pagoda_preschool_classes, pagoda_primary_schools, pagoda_primary_classes, pagoda_junior_high_schools, pagoda_junior_high_classes
# ...

# %%
kabdsjf=df[df['Year']==2025]
kabdsjf.shape
# Out:
# (25, 263)

# %%
df.to_csv('cleaned_new_data.csv', index=False)
